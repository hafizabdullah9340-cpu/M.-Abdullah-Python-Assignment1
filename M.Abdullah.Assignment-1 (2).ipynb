# %% [markdown]
# # Question No.1
# Division of two numbers

# %%
a=20
b=100
print(a/b)
# Out:
# 0.2

# %% [markdown]
# # Question No.2
# Create a variable with your name and print it. Then print in in a lowercase

# %%
name=("Abdullah")

# %%
print(name.lower())
# Out:
# abdullah

# %% [markdown]
# # Question No.3
# Covert the string" hello world from python" into title case

# %%
x= ("hello world From python")

# %%
print(x)
# Out:
# hello world From python

# %%
print(x.title())
# Out:
# Hello World From Python

# %% [markdown]
# # Question No.4
# Create two variables and print heir modulus.

# %%
c= 100
d= 20
print(c%d)
# Out:
# 0

# %% [markdown]
# # Question No.5
# convert the string " PYTHON" into lowercase.

# %%
word= ("PYTHON")
print(word.lower())
# Out:
# python

# %% [markdown]
# # Question No.6
# Find the length of the string" Data Science"

# %%
v= ("Data Science")
print(len(v))
# Out:
# 12

# %% [markdown]
# # Question No.7
# Find the square of the number 7.

# %%
7**2
# Out:
# 49

# %% [markdown]
# # Quesion No.8
# Repeat the string"hello" three times.

# %%
g= ("hello")
print(g*3)
# Out:
# hellohellohello

# %% [markdown]
# # Question No.9
# Check wheather 15 is greater than 10

# %%
15>10
# Out:
# True

# %% [markdown]
# # Question N0.10
# Capitalize the first letter of the string" i love Python programming"

# %%
z= ("i love python programming language")
print(z.capitalize())
# Out:
# I love python programming language
